# %%
import pandas as pd

# %%
df = pd.read_csv("corporate_rating.csv")
df.head()
# Out:
#   Rating                   Name Symbol                  Rating Agency Name  \
# 0      A  Whirlpool Corporation    WHR          Egan-Jones Ratings Company
# 1    BBB  Whirlpool Corporation    WHR          Egan-Jones Ratings Company
# 2    BBB  Whirlpool Corporation    WHR                       Fitch Ratings
# 3    BBB  Whirlpool Corporation    WHR                       Fitch Ratings
# 4    BBB  Whirlpool Corporation    WHR  Standard & Poor's Ratings Services
#
#          Date             Sector  currentRatio  quickRatio  cashRatio  \
# 0  11/27/2015  Consumer Durables      0.945894    0.426395   0.099690
# 1   2/13/2014  Consumer Durables      1.033559    0.498234   0.203120
# 2    3/6/2015  Consumer Durables      0.963703    0.451505   0.122099
# 3   6/15/2012  Consumer Durables      1.019851    0.510402   0.176116
# 4  10/24/2016  Consumer Durables      0.957844    0.495432   0.141608
#
#    daysOfSalesOutstanding  ...  effectiveTaxRate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2029 entries, 0 to 2028
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Rating                              2029 non-null   object
#  1   Name                                2029 non-null   object
#  2   Symbol                              2029 non-null   object
#  3   Rating Agency Name                  2029 non-null   object
#  4   Date                                2029 non-null   object
#  5   Sector                              2029 non-null   object
#  6   currentRatio                        2029 non-null   float64
#  7   quickRatio                          2029 non-null   float64
#  8   cashRatio                           2029 non-null   float64
#  9   daysOfSalesOutstanding              2029 non-null   float64
#  10  netProfitMargin                     2029 non-null   float64
# ...

# %%
df['Sector'].unique()
# Out:
# array(['Consumer Durables', 'Energy', 'Capital Goods',
#        'Consumer Non-Durables', 'Public Utilities', 'Technology',
#        'Health Care', 'Consumer Services', 'Miscellaneous',
#        'Basic Industries', 'Finance', 'Transportation'], dtype=object)

# %%
sector_mapping = {
    'Consumer Durables': 'Project Developers',
    'Energy': 'EPC Providers, O&M Providers, Utility Companies, Project Developers',
    'Capital Goods': 'EPC Providers, O&M Providers',
    'Consumer Non-Durables': 'Project Developers',
    'Public Utilities': 'Utility Companies, O&M Providers',
    'Technology': 'O&M Providers, Project Developers',
    'Health Care': 'Project Developers',
    'Consumer Services': 'Project Developers',
    'Miscellaneous': 'Varies',
    'Basic Industries': 'EPC Providers, O&M Providers',
    'Finance': 'Indirect Role (e.g., Funding via Project Developers)',
    'Transportation': 'EPC Providers, O&M Providers'
}

# Apply mapping to the dataframe
df['Mapped Category'] = df['Sector'].map(sector_mapping)

# %%
rating_dict = {'AAA':'Lowest Risk', 
               'AA':'Low Risk',
               'A':'Low Risk',
               'BBB':'Medium Risk', 
               'BB':'High Risk',
               'B':'High Risk',
               'CCC':'Highest Risk', 
               'CC':'Highest Risk',
               'C':'Highest Risk',
               'D':'In Default'}

df.Rating = df.Rating.map(rating_dict)

# %%
# donwload csv here with rating on differnt years
df.to_csv('Rating_with_history.csv', index=False)

# %%
rating_to_score = {
    'Lowest Risk' : 5 , 'Low Risk' : 4 , 'Medium Risk' : 3 , 'High Risk' : 2 , 'Highest Risk':1
}

# Map ratings to numerical scores
df['Rating_Score'] = df['Rating'].map(rating_to_score)

# Calculate the average score for each company
aggregated = df.groupby('Name').agg(
    Average_Score=('Rating_Score', 'mean')  # Calculate the average of numeric scores
).reset_index()

# Optionally map the average score back to categorical ratings
score_to_rating = {v: k for k, v in rating_to_score.items()}
aggregated['Average_Rating'] = aggregated['Average_Score'].apply(lambda x: score_to_rating[round(x)])

# Display results
print(aggregated)
# Out:
#                                Name  Average_Score Average_Rating
# 0                        3M Company            4.0       Low Risk
# 1                           ABB Ltd            4.0       Low Risk
# 2               ACI Worldwide, Inc.            2.0      High Risk
# 3                          ADT Inc.            2.0      High Risk
# 4                             AECOM            2.0      High Risk
# ..                              ...            ...            ...
# 588                Yamana Gold Inc.            2.5      High Risk
# 589               Yum! Brands, Inc.            3.0    Medium Risk
# 590  Zebra Technologies Corporation            2.0      High Risk
# 591                     Zoetis Inc.            3.0    Medium Risk
# 592                       eBay Inc.            4.0       Low Risk
#
# [593 rows x 3 columns]

# %%
aggregated.to_csv("Rating_without_history.csv",index=False)

# %%
df[Name=="Matrix Service Compan"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df[Name=="Matrix Service Compan"]
#
# NameError: name 'Name' is not defined
